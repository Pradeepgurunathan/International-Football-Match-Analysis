# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import glob 
import os

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('results.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41640 entries, 0 to 41639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        41640 non-null  object
#  1   home_team   41640 non-null  object
#  2   away_team   41640 non-null  object
#  3   home_score  41640 non-null  int64
#  4   away_score  41640 non-null  int64
#  5   tournament  41640 non-null  object
#  6   city        41640 non-null  object
#  7   country     41640 non-null  object
#  8   neutral     41640 non-null  bool
# dtypes: bool(1), int64(2), object(6)
# memory usage: 2.6+ MB

# %%
def label_race (row):
    if row['home_score']> row['away_score']:
          return row['home_team']
    if row['home_score']< row['away_score']:
          return row['away_team']
    return 'DRAW'

df['winner']=df.apply (lambda row: label_race(row), axis=1)

# %%
def label_race (row):
    if row['home_score']< row['away_score']:
          return row['home_team']
    if row['home_score']> row['away_score']:
          return row['away_team']
    return 'DRAW'

df['loser']=df.apply (lambda row: label_race(row), axis=1)

# %%
df.head(20)
# Out:
#           date         home_team away_team  home_score  away_score tournament  \
# 0   1872-11-30          Scotland   England           0           0   Friendly
# 1   1873-03-08           England  Scotland           4           2   Friendly
# 2   1874-03-07          Scotland   England           2           1   Friendly
# 3   1875-03-06           England  Scotland           2           2   Friendly
# 4   1876-03-04          Scotland   England           3           0   Friendly
# 5   1876-03-25          Scotland     Wales           4           0   Friendly
# 6   1877-03-03           England  Scotland           1           3   Friendly
# 7   1877-03-05             Wales  Scotland           0           2   Friendly
# 8   1878-03-02          Scotland   England           7           2   Friendly
# 9   1878-03-23          Scotland     Wales           9           0   Friendly
# 10  1879-01-18           England     Wales           2           1   Friendly
# ...

# %%
country=pd.DataFrame()

# %%
loser=pd.DataFrame()

# %%
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].dt.year

# %%
country=df.groupby(['winner','year']).count()

# %%
type(country)
# Out:
# pandas.core.frame.DataFrame

# %%
country.index
# Out:
# MultiIndex([(     'Abkhazia', 2014),
#             (     'Abkhazia', 2016),
#             (     'Abkhazia', 2017),
#             (     'Abkhazia', 2018),
#             (     'Abkhazia', 2019),
#             (  'Afghanistan', 1976),
#             (  'Afghanistan', 2003),
#             (  'Afghanistan', 2005),
#             (  'Afghanistan', 2008),
#             (  'Afghanistan', 2011),
#             ...
#             ('Åland Islands', 1991),
#             ('Åland Islands', 1993),
#             ('Åland Islands', 1995),
#             ('Åland Islands', 1999),
#             ('Åland Islands', 2005),
#             ('Åland Islands', 2007),
#             ('Åland Islands', 2009),
#             ('Åland Islands', 2011),
#             ('Åland Islands', 2015),
#             ('Åland Islands', 2017)],
#            names=['winner', 'year'], length=9538)

# %%
country=country.add_suffix('_Count').reset_index()

# %%
country.drop(['home_team_Count','away_team_Count','home_score_Count','away_score_Count','tournament_Count','city_Count','date_Count','neutral_Count','loser_Count'], axis=1,inplace=True)

# %%
country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9538 entries, 0 to 9537
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   winner         9538 non-null   object
#  1   year           9538 non-null   int64
#  2   country_Count  9538 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 223.7+ KB

# %%
country
# Out:
#              winner  year  country_Count
# 0          Abkhazia  2014              1
# 1          Abkhazia  2016              4
# 2          Abkhazia  2017              1
# 3          Abkhazia  2018              4
# 4          Abkhazia  2019              2
# ...             ...   ...            ...
# 9533  Åland Islands  2007              2
# 9534  Åland Islands  2009              3
# 9535  Åland Islands  2011              1
# 9536  Åland Islands  2015              1
# 9537  Åland Islands  2017              2
#
# [9538 rows x 3 columns]

# %%
country.to_csv('country_winner.csv', index=False)

# %%
loser=df.groupby(['loser','year']).count()

# %%
loser=loser.add_suffix('_Count').reset_index()

# %%
loser.drop(['home_team_Count','away_team_Count','home_score_Count','away_score_Count','tournament_Count','city_Count','date_Count','neutral_Count','winner_Count'], axis=1,inplace=True)

# %%
loser
# Out:
#                loser  year  country_Count
# 0           Abkhazia  2012              1
# 1           Abkhazia  2014              1
# 2           Abkhazia  2017              1
# 3           Abkhazia  2018              1
# 4        Afghanistan  1941              1
# ...              ...   ...            ...
# 10735  Åland Islands  2005              3
# 10736  Åland Islands  2007              2
# 10737  Åland Islands  2009              1
# 10738  Åland Islands  2011              2
# 10739  Åland Islands  2015              2
#
# [10740 rows x 3 columns]

# %%
loser.to_csv('loser_winner.csv', index=False)

# %%
df = pd.read_csv('loser_winner.csv')

# %%
df
# Out:
#                loser  year  country_Count
# 0           Abkhazia  2012              1
# 1           Abkhazia  2014              1
# 2           Abkhazia  2017              1
# 3           Abkhazia  2018              1
# 4        Afghanistan  1941              1
# ...              ...   ...            ...
# 10735  Åland Islands  2005              3
# 10736  Åland Islands  2007              2
# 10737  Åland Islands  2009              1
# 10738  Åland Islands  2011              2
# 10739  Åland Islands  2015              2
#
# [10740 rows x 3 columns]

# %%
df.head(50)
# Out:
#           loser  year  country_Count
# 0      Abkhazia  2012              1
# 1      Abkhazia  2014              1
# 2      Abkhazia  2017              1
# 3      Abkhazia  2018              1
# 4   Afghanistan  1941              1
# 5   Afghanistan  1950              1
# 6   Afghanistan  1975              5
# 7   Afghanistan  1976              1
# 8   Afghanistan  1977              1
# 9   Afghanistan  1979              1
# 10  Afghanistan  1984              3
# 11  Afghanistan  2003              6
# 12  Afghanistan  2005              3
# 13  Afghanistan  2007              2
# 14  Afghanistan  2008              5
# 15  Afghanistan  2009              2
# 16  Afghanistan  2010              1
# 17  Afghanistan  2011              4
# 18  Afghanistan  2013              1
# 19  Afghanistan  2014              2
# 20  Afghanistan  2015              6
# 21  Afghanistan  2016              4
# 22  Afghanistan  2017              3
# 23  Afghanistan  2018              1
# ...

# %%
df['cumsum']=df.groupby('loser').country_Count.cumsum()

# %%
df.head(50)
# Out:
#           loser  year  country_Count  cumsum
# 0      Abkhazia  2012              1       1
# 1      Abkhazia  2014              1       2
# 2      Abkhazia  2017              1       3
# 3      Abkhazia  2018              1       4
# 4   Afghanistan  1941              1       1
# 5   Afghanistan  1950              1       2
# 6   Afghanistan  1975              5       7
# 7   Afghanistan  1976              1       8
# 8   Afghanistan  1977              1       9
# 9   Afghanistan  1979              1      10
# 10  Afghanistan  1984              3      13
# 11  Afghanistan  2003              6      19
# 12  Afghanistan  2005              3      22
# 13  Afghanistan  2007              2      24
# 14  Afghanistan  2008              5      29
# 15  Afghanistan  2009              2      31
# 16  Afghanistan  2010              1      32
# 17  Afghanistan  2011              4      36
# 18  Afghanistan  2013              1      37
# 19  Afghanistan  2014              2      39
# ...

# %%
df.to_csv('country_loser.csv', index=False)

# %%
df = pd.read_csv('country_winner.csv')

# %%
df['cumsum']=df.groupby('winner').country_Count.cumsum()
df.to_csv('country_winner.csv', index=False)

# %%
df.head(50)
# Out:
#          winner  year  country_Count  cumsum
# 0      Abkhazia  2014              1       1
# 1      Abkhazia  2016              4       5
# 2      Abkhazia  2017              1       6
# 3      Abkhazia  2018              4      10
# 4      Abkhazia  2019              2      12
# 5   Afghanistan  1976              1       1
# 6   Afghanistan  2003              1       2
# 7   Afghanistan  2005              1       3
# 8   Afghanistan  2008              1       4
# 9   Afghanistan  2011              6      10
# 10  Afghanistan  2013              6      16
# 11  Afghanistan  2014              2      18
# 12  Afghanistan  2015              7      25
# 13  Afghanistan  2016              1      26
# 14  Afghanistan  2017              2      28
# 15  Afghanistan  2018              1      29
# 16  Afghanistan  2019              1      30
# 17      Albania  1946              3       3
# 18      Albania  1948              1       4
# 19      Albania  1950              1       5
# ...

# %%
df = pd.read_csv('country_loser.csv')

# %%
df
# Out:
#                loser  year  country_Count  cumsum
# 0           Abkhazia  2012              1       1
# 1           Abkhazia  2014              1       2
# 2           Abkhazia  2017              1       3
# 3           Abkhazia  2018              1       4
# 4        Afghanistan  1941              1       1
# ...              ...   ...            ...     ...
# 10735  Åland Islands  2005              3      12
# 10736  Åland Islands  2007              2      14
# 10737  Åland Islands  2009              1      15
# 10738  Åland Islands  2011              2      17
# 10739  Åland Islands  2015              2      19
#
# [10740 rows x 4 columns]

# %%
for x in df.loser.unique():
    y=df.loc[df['loser'] == x].year
    for yr in range(df.year.min(),df.year.max()+1):
        b=False
        for a in y:
            if yr==a:
                b=True
        if b==False:
            print(yr)
            df=df.append({'loser':x, 'year':yr,'country_Count':0}, ignore_index=True)
# Out:
# 1872
# 1873
# 1874
# 1875
# 1876
# 1877
# 1878
# 1879
# 1880
# 1881
# 1882
# 1883
# 1884
# 1885
# 1886
# 1887
# 1888
# 1889
# 1890
# 1891
# 1892
# 1893
# 1894
# 1895
# 1896
# 1897
# 1898
# 1899
# 1900
# 1901
# 1902
# 1903
# 1904
# 1905
# 1906
# 1907
# 1908
# 1909
# 1910
# 1911
# 1912
# 1913
# 1914
# 1915
# 1916
# 1917
# 1918
# 1919
# 1920
# 1921
# 1922
# 1923
# 1924
# 1925
# 1926
# 1927
# 1928
# 1929
# 1930
# 1931
# 1932
# 1933
# 1934
# 1935
# 1936
# 1937
# 1938
# 1939
# 1940
# 1941
# 1942
# 1943
# 1944
# 1945
# 1946
# 1947
# 1948
# 1949
# 1950
# 1951
# 1952
# 1953
# 1954
# 1955
# 1956
# 1957
# 1958
# 1959
# 1960
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2013
# 2015
# ...

# %%
df
# Out:
#                loser  year  country_Count  cumsum
# 0           Abkhazia  2012              1     1.0
# 1           Abkhazia  2014              1     2.0
# 2           Abkhazia  2017              1     3.0
# 3           Abkhazia  2018              1     4.0
# 4        Afghanistan  1941              1     1.0
# ...              ...   ...            ...     ...
# 46334  Åland Islands  2016              0     NaN
# 46335  Åland Islands  2017              0     NaN
# 46336  Åland Islands  2018              0     NaN
# 46337  Åland Islands  2019              0     NaN
# 46338  Åland Islands  2020              0     NaN
#
# [46339 rows x 4 columns]

# %%
df['cumsum']=df.groupby('loser').country_Count.cumsum()

# %%
df.to_csv('country_loser.csv', index=False)

# %%
df = pd.read_csv('country_winner.csv')

# %%
df
# Out:
#              winner  year  country_Count  cumsum
# 0          Abkhazia  2014              1       1
# 1          Abkhazia  2016              4       5
# 2          Abkhazia  2017              1       6
# 3          Abkhazia  2018              4      10
# 4          Abkhazia  2019              2      12
# ...             ...   ...            ...     ...
# 9533  Åland Islands  2007              2      14
# 9534  Åland Islands  2009              3      17
# 9535  Åland Islands  2011              1      18
# 9536  Åland Islands  2015              1      19
# 9537  Åland Islands  2017              2      21
#
# [9538 rows x 4 columns]

# %%
df.winner.nunique()
# Out:
# 301

# %%
for x in df.winner.unique():
    y=df.loc[df['winner'] == x].year
    for yr in range(df.year.min(),df.year.max()+1):
        b=False
        for a in y:
            if yr==a:
                b=True
        if b==False:
            print(yr)
            df=df.append({'winner':x, 'year':yr,'country_Count':0}, ignore_index=True)
# Out:
# 1872
# 1873
# 1874
# 1875
# 1876
# 1877
# 1878
# 1879
# 1880
# 1881
# 1882
# 1883
# 1884
# 1885
# 1886
# 1887
# 1888
# 1889
# 1890
# 1891
# 1892
# 1893
# 1894
# 1895
# 1896
# 1897
# 1898
# 1899
# 1900
# 1901
# 1902
# 1903
# 1904
# 1905
# 1906
# 1907
# 1908
# 1909
# 1910
# 1911
# 1912
# 1913
# 1914
# 1915
# 1916
# 1917
# 1918
# 1919
# 1920
# 1921
# 1922
# 1923
# 1924
# 1925
# 1926
# 1927
# 1928
# 1929
# 1930
# 1931
# 1932
# 1933
# 1934
# 1935
# 1936
# 1937
# 1938
# 1939
# 1940
# 1941
# 1942
# 1943
# 1944
# 1945
# 1946
# 1947
# 1948
# 1949
# 1950
# 1951
# 1952
# 1953
# 1954
# 1955
# 1956
# 1957
# 1958
# 1959
# 1960
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# ...

# %%
df
# Out:
#               winner  year  country_Count  cumsum
# 0           Abkhazia  2014              1     1.0
# 1           Abkhazia  2016              4     5.0
# 2           Abkhazia  2017              1     6.0
# 3           Abkhazia  2018              4    10.0
# 4           Abkhazia  2019              2    12.0
# ...              ...   ...            ...     ...
# 44844  Åland Islands  2014              0     NaN
# 44845  Åland Islands  2016              0     NaN
# 44846  Åland Islands  2018              0     NaN
# 44847  Åland Islands  2019              0     NaN
# 44848  Åland Islands  2020              0     NaN
#
# [44849 rows x 4 columns]

# %%
df['cumsum']=df.groupby('winner').country_Count.cumsum()

# %%
df
# Out:
#               winner  year  country_Count  cumsum
# 0           Abkhazia  2014              1       1
# 1           Abkhazia  2016              4       5
# 2           Abkhazia  2017              1       6
# 3           Abkhazia  2018              4      10
# 4           Abkhazia  2019              2      12
# ...              ...   ...            ...     ...
# 44844  Åland Islands  2014              0      21
# 44845  Åland Islands  2016              0      21
# 44846  Åland Islands  2018              0      21
# 44847  Åland Islands  2019              0      21
# 44848  Åland Islands  2020              0      21
#
# [44849 rows x 4 columns]

# %%
df.to_csv('country_winner.csv', index=False)

# %%
df=df.sort_values(['winner','year']).reset_index(drop=True)

# %%
df['cumsum']=df.groupby('winner').country_Count.cumsum()

# %%
df
# Out:
#               winner  year  country_Count  cumsum
# 0           Abkhazia  1872              0       0
# 1           Abkhazia  1873              0       0
# 2           Abkhazia  1874              0       0
# 3           Abkhazia  1875              0       0
# 4           Abkhazia  1876              0       0
# ...              ...   ...            ...     ...
# 44844  Åland Islands  2016              0      19
# 44845  Åland Islands  2017              2      21
# 44846  Åland Islands  2018              0      21
# 44847  Åland Islands  2019              0      21
# 44848  Åland Islands  2020              0      21
#
# [44849 rows x 4 columns]

# %%
df.to_csv('country_winner.csv', index=False)

# %%
df = pd.read_csv('country_winner.csv')

# %%
df
# Out:
#               winner  year  country_Count  cumsum
# 0           Abkhazia  1872              0       0
# 1           Abkhazia  1873              0       0
# 2           Abkhazia  1874              0       0
# 3           Abkhazia  1875              0       0
# 4           Abkhazia  1876              0       0
# ...              ...   ...            ...     ...
# 44844  Åland Islands  2016              0      19
# 44845  Åland Islands  2017              2      21
# 44846  Åland Islands  2018              0      21
# 44847  Åland Islands  2019              0      21
# 44848  Åland Islands  2020              0      21
#
# [44849 rows x 4 columns]

# %%
df = pd.read_csv('country_loser.csv')

# %%
df
# Out:
#                loser  year  country_Count  cumsum
# 0           Abkhazia  2012              1       1
# 1           Abkhazia  2014              1       2
# 2           Abkhazia  2017              1       3
# 3           Abkhazia  2018              1       4
# 4        Afghanistan  1941              1       1
# ...              ...   ...            ...     ...
# 46334  Åland Islands  2016              0      19
# 46335  Åland Islands  2017              0      19
# 46336  Åland Islands  2018              0      19
# 46337  Åland Islands  2019              0      19
# 46338  Åland Islands  2020              0      19
#
# [46339 rows x 4 columns]

# %%
df=df.sort_values(['loser','year']).reset_index(drop=True)

# %%
df
# Out:
#                loser  year  country_Count  cumsum
# 0           Abkhazia  1872              0       4
# 1           Abkhazia  1873              0       4
# 2           Abkhazia  1874              0       4
# 3           Abkhazia  1875              0       4
# 4           Abkhazia  1876              0       4
# ...              ...   ...            ...     ...
# 46334  Åland Islands  2016              0      19
# 46335  Åland Islands  2017              0      19
# 46336  Åland Islands  2018              0      19
# 46337  Åland Islands  2019              0      19
# 46338  Åland Islands  2020              0      19
#
# [46339 rows x 4 columns]

# %%
df['cumsum']=df.groupby('loser').country_Count.cumsum()

# %%
df
# Out:
#                loser  year  country_Count  cumsum
# 0           Abkhazia  1872              0       0
# 1           Abkhazia  1873              0       0
# 2           Abkhazia  1874              0       0
# 3           Abkhazia  1875              0       0
# 4           Abkhazia  1876              0       0
# ...              ...   ...            ...     ...
# 46334  Åland Islands  2016              0      19
# 46335  Åland Islands  2017              0      19
# 46336  Åland Islands  2018              0      19
# 46337  Åland Islands  2019              0      19
# 46338  Åland Islands  2020              0      19
#
# [46339 rows x 4 columns]

# %%
df.to_csv('country_loser.csv', index=False)

# %%
df = pd.read_csv('country_loser.csv')

# %%
df
# Out:
#                loser  year  country_Count  cumsum
# 0           Abkhazia  1872              0       0
# 1           Abkhazia  1873              0       0
# 2           Abkhazia  1874              0       0
# 3           Abkhazia  1875              0       0
# 4           Abkhazia  1876              0       0
# ...              ...   ...            ...     ...
# 46334  Åland Islands  2016              0      19
# 46335  Åland Islands  2017              0      19
# 46336  Åland Islands  2018              0      19
# 46337  Åland Islands  2019              0      19
# 46338  Åland Islands  2020              0      19
#
# [46339 rows x 4 columns]
